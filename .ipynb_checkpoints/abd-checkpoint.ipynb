# %% [markdown]
# # "Анализ больших данных"
# - Подготовил: Колесниченко Олег Сергеевич, 1 курс магистратуры, ВГУ, ФКН.
# - Данные: Жилые дома в Эймсе, штат Айова.
# - Источник данных: https://www.kaggle.com/c/home-data-for-ml-course

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt

# %% [markdown]
# ## CSV файлы с тестовыми и обучающими данными
# Данные взяты с ресурса www.kaggle.com. Включают в себя выборки для обучения и тестовую выборку.

# %%
train_file_path = "train.csv"
test_file_path = "test.csv"
train_data = pd.read_csv(train_file_path, index_col='Id')
test_data = pd.read_csv(test_file_path,  index_col='Id')

# %%
train_data.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1        0      2    2008        WD         Normal     208500
# 2        0      5    2007        WD         Normal     181500
# 3        0      9    2008        WD         Normal     223500
# 4        0      2    2006        WD        Abnorml     140000
# 5        0     12    2008        WD         Normal     250000
#
# [5 rows x 80 columns]

# %%
train_data.columns
data = pd.Index(train_data['YrSold'])
data = data.value_counts()
plt.pie(data, labels = data.index, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7ff015904828>,
#   <matplotlib.patches.Wedge at 0x7ff01591b080>,
#   <matplotlib.patches.Wedge at 0x7ff01591b7b8>,
#   <matplotlib.patches.Wedge at 0x7ff01591bef0>,
#   <matplotlib.patches.Wedge at 0x7ff015929668>],
#  [Text(0.8216692850227645, 0.7313409506175483, '2009'),
#   Text(-0.6135851383502949, 0.9129694836059141, '2007'),
#   Text(-1.0112145538079116, -0.4329493344111597, '2006'),
#   Text(0.17908775863688034, -1.085323718853697, '2008'),
#   Text(1.022928328929569, -0.40449676620877917, '2010')],
#  [Text(0.4481832463760533, 0.3989132457913899, '23.2%'),
#   Text(-0.3346828027365245, 0.4979833546941349, '22.5%'),
#   Text(-0.5515715748043154, -0.23615418240608704, '21.5%'),
#   Text(0.0976842319837529, -0.5919947557383801, '20.8%'),
#   Text(0.5579609066888558, -0.22063459975024316, '12.0%')])

# %% [markdown]
# ## Описание данных
# Данный датафрейм включает в себя описание данных по колонкам содержащим числовые данные.

# %%
train_data.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# std      30.202904     20.645407   181.066207   456.098091   161.319273  ...
# min    1872.000000   1950.000000     0.000000     0.000000     0.000000  ...
# 25%    1954.000000   1967.000000     0.000000     0.000000     0.000000  ...
# 50%    1973.000000   1994.000000     0.000000   383.500000     0.000000  ...
# 75%    2000.000000   2004.000000   166.000000   712.250000     0.000000  ...
# max    2010.000000   2010.000000  1600.000000  5644.000000  1474.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 37 columns]

# %% [markdown]
# ## Удалим строки с отсутствующей ценой дома
# Одним из этапов подготовки данных явлется отчистка данных от нулевых значений. Данный фрагмент кода очищает строки данных с отсутствующей ценой.

# %%
X_full = train_data
X_test_full = test_data
X_full.dropna(axis=0, subset=['SalePrice'], inplace=True)
y = X_full.SalePrice
X_full.drop(['SalePrice'], axis=1, inplace=True)
X_full
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# Id                                    ...
# 1            Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 2            Lvl    AllPub       FR2  ...           0        0    NaN    NaN
# 3            Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 4            Lvl    AllPub    Corner  ...           0        0    NaN    NaN
# 5            Lvl    AllPub       FR2  ...           0        0    NaN    NaN
# ...          ...       ...       ...  ...         ...      ...    ...    ...
# 1456         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1457         Lvl    AllPub    Inside  ...           0        0    NaN  MnPrv
# 1458         Lvl    AllPub    Inside  ...           0        0    NaN  GdPrv
# 1459         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1460         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
#
#      MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# Id
# 1            NaN       0       2    2008        WD         Normal
# 2            NaN       0       5    2007        WD         Normal
# 3            NaN       0       9    2008        WD         Normal
# 4            NaN       0       2    2006        WD        Abnorml
# 5            NaN       0      12    2008        WD         Normal
# ...          ...     ...     ...     ...       ...            ...
# 1456         NaN       0       8    2007        WD         Normal
# 1457         NaN       0       2    2010        WD         Normal
# 1458        Shed    2500       5    2010        WD         Normal
# 1459         NaN       0       4    2010        WD         Normal
# 1460         NaN       0       6    2008        WD         Normal
#
# [1460 rows x 79 columns]

# %% [markdown]
# ## Используем только числовые значения
# В качестве данных для обучения выбираем только признаки с числовыми значениями.

# %%
X = X_full.select_dtypes(exclude=['object'])
X_test = X_test_full.select_dtypes(exclude=['object'])
X
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 1             60         65.0     8450            7            5       2003
# 2             20         80.0     9600            6            8       1976
# 3             60         68.0    11250            7            5       2001
# 4             70         60.0     9550            7            5       1915
# 5             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1456          60         62.0     7917            6            5       1999
# 1457          20         85.0    13175            6            6       1978
# 1458          70         66.0     9042            7            9       1941
# 1459          20         68.0     9717            5            6       1950
# 1460          20         75.0     9937            5            6       1965
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  GarageArea  \
# Id                                                      ...
# 1             2003       196.0         706           0  ...         548
# 2             1976         0.0         978           0  ...         460
# 3             2002       162.0         486           0  ...         608
# 4             1970         0.0         216           0  ...         642
# 5             2000       350.0         655           0  ...         836
# ...            ...         ...         ...         ...  ...         ...
# 1456          2000         0.0           0           0  ...         460
# 1457          1988       119.0         790         163  ...         500
# 1458          2006         0.0         275           0  ...         252
# 1459          1996         0.0          49        1029  ...         240
# 1460          1965         0.0         830         290  ...         276
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# Id
# 1              0           61              0          0            0
# 2            298            0              0          0            0
# 3              0           42              0          0            0
# 4              0           35            272          0            0
# 5            192           84              0          0            0
# ...          ...          ...            ...        ...          ...
# 1456           0           40              0          0            0
# 1457         349            0              0          0            0
# 1458           0           60              0          0            0
# 1459         366            0            112          0            0
# 1460         736           68              0          0            0
#
#       PoolArea  MiscVal  MoSold  YrSold
# Id
# 1            0        0       2    2008
# 2            0        0       5    2007
# 3            0        0       9    2008
# 4            0        0       2    2006
# 5            0        0      12    2008
# ...        ...      ...     ...     ...
# 1456         0        0       8    2007
# 1457         0        0       2    2010
# 1458         0     2500       5    2010
# 1459         0        0       4    2010
# 1460         0        0       6    2008
#
# [1460 rows x 36 columns]

# %% [markdown]
# ## Разделим на данные проверки и обучения

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2,
                                                      random_state=0)
X_train.head()
# Out:
#      MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 619          20         90.0    11694            9            5       2007
# 871          20         60.0     6600            5            5       1962
# 93           30         80.0    13360            5            7       1921
# 818          20          NaN    13265            8            5       2002
# 303          20        118.0    13704            7            5       2001
#
#      YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  GarageArea  \
# Id                                                     ...
# 619          2007       452.0          48           0  ...         774
# 871          1962         0.0           0           0  ...         308
# 93           2006         0.0         713           0  ...         432
# 818          2002       148.0        1218           0  ...         857
# 303          2002       150.0           0           0  ...         843
#
#      WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# Id
# 619           0          108              0          0          260         0
# 871           0            0              0          0            0         0
# 93            0            0             44          0            0         0
# 818         150           59              0          0            0         0
# 303         468           81              0          0            0         0
#
#      MiscVal  MoSold  YrSold
# Id
# 619        0       7    2007
# 871        0       8    2009
# 93         0       8    2009
# 818        0       7    2008
# 303        0       1    2006
#
# [5 rows x 36 columns]

# %% [markdown]
# ## Количество пропущенных значений в каждом столбце данных обучения

# %%
missing_val_count_by_column = (X_train.isnull().sum())
print(missing_val_count_by_column[missing_val_count_by_column > 0])
# Out:
# LotFrontage    212
# MasVnrArea       6
# GarageYrBlt     58
# dtype: int64

# %% [markdown]
# ### Для решения этой проблемы заполним пропущенные значения некоторым числом. Например, мы можем заполнить среднее значение по каждому столбцу.

# %%
from sklearn.impute import SimpleImputer

my_imputer = SimpleImputer(strategy='median')
imputed_X_train = pd.DataFrame(my_imputer.fit_transform(X_train))
imputed_X_valid = pd.DataFrame(my_imputer.transform(X_valid))

imputed_X_train.columns = X_train.columns
imputed_X_valid.columns = X_valid.columns

# %% [markdown]
# ## Рассмотрим значения среднеквадратичного отклонения в зависимости от выбранной модели
#
# Для этого опеределим 5 моделей с различными параметрами и выберем лучшую из них.

# %%
from sklearn.ensemble import RandomForestRegressor

model_1 = RandomForestRegressor(n_estimators=50, random_state=0)
model_2 = RandomForestRegressor(n_estimators=100, random_state=0)
model_3 = RandomForestRegressor(n_estimators=100, criterion='mae', random_state=0)
model_4 = RandomForestRegressor(n_estimators=200, min_samples_split=20, random_state=0)
model_5 = RandomForestRegressor(n_estimators=100, max_depth=7, random_state=0)

models = [model_1, model_2, model_3, model_4, model_5]

# %%
def score_model(model, X_t=imputed_X_train, X_v=imputed_X_valid, y_t=y_train, y_v=y_valid):
    model.fit(X_t, y_t)
    preds = model.predict(X_v)
    return mean_absolute_error(y_v, preds)

mae = []

for i in range(0, len(models)):
    mae.append(score_model(models[i]))
    
data = mae
models = [1, 2, 3, 4, 5]
plt.figure(figsize=(9,5))
plt.bar(models, data)
plt.xlabel('Модели')
plt.ylabel('Среднеквадратическая ошибка')
plt.show()

# %% [markdown]
# ## Используем модель с наименьшей ошибкой

# %%
#final_X_train = pd.DataFrame(my_imputer.fit_transform(X_train))
#final_X_valid = pd.DataFrame(my_imputer.transform(X_valid))
#model = RandomForestRegressor(n_estimators=100, criterion='mae', random_state=0)
#model.fit(final_X_train, y_train)
final_X_test = pd.DataFrame(my_imputer.fit_transform(X_test))
preds_test = model_3.predict(final_X_test)

# %% [markdown]
# Результат предсказания записываем в файл submission.csv

# %%
output = pd.DataFrame({'Id': X_test.index,
                       'SalePrice': preds_test})
output.to_csv('submission.csv', index=False)
